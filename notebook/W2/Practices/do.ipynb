# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../../../datasets/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.stack().unstack(level=0)
# Out:
#                0       1       2       3       4       5       6       7    \
# total_bill   16.99   10.34   21.01   23.68   24.59   25.29    8.77   26.88
# tip           1.01    1.66     3.5    3.31    3.61    4.71     2.0    3.12
# sex         Female    Male    Male    Male  Female    Male    Male    Male
# smoker          No      No      No      No      No      No      No      No
# day            Sun     Sun     Sun     Sun     Sun     Sun     Sun     Sun
# time        Dinner  Dinner  Dinner  Dinner  Dinner  Dinner  Dinner  Dinner
# size             2       3       3       2       4       4       2       4
#
#                8       9    ...     234     235     236     237     238  \
# total_bill   15.04   14.78  ...   15.53   10.07    12.6   32.83   35.83
# tip           1.96    3.23  ...     3.0    1.25     1.0    1.17    4.67
# sex           Male    Male  ...    Male    Male    Male    Male  Female
# smoker          No      No  ...     Yes      No     Yes     Yes      No
# ...

# %%
df.unstack(level=0)
# Out:
# total_bill  0      16.99
#             1      10.34
#             2      21.01
#             3      23.68
#             4      24.59
#                    ...
# size        239        3
#             240        2
#             241        2
#             242        2
#             243        2
# Length: 1708, dtype: object

# %%
df.stack()
# Out:
# 0    total_bill     16.99
#      tip             1.01
#      sex           Female
#      smoker            No
#      day              Sun
#                     ...
# 243  sex           Female
#      smoker            No
#      day             Thur
#      time          Dinner
#      size               2
# Length: 1708, dtype: object

# %%
dd = pd.DataFrame(np.arange(12).reshape(6,2),index=[['a','a','a','b','b','c'],[1,2,3,1,2,1]],columns=[['z','x'],['q','w']]
            )
dd
# Out:
#       z   x
#       q   w
# a 1   0   1
#   2   2   3
#   3   4   5
# b 1   6   7
#   2   8   9
# c 1  10  11

# %%
dd.index.names = ["key1", "key2"]

# %%
dd.index.nlevels
# Out:
# 2

# %%
dd.swaplevel('key2','key1')
# Out:
#             z   x
#             q   w
# key2 key1
# 1    a      0   1
# 2    a      2   3
# 3    a      4   5
# 1    b      6   7
# 2    b      8   9
# 1    c     10  11

# %%
df2 = pd.read_csv('../../../datasets/tips.csv')
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2.dropna()
df2.pivot(columns='tip',values='sex')
# Out:
# tip 1.00    1.01  1.10  1.17  1.25  1.32  1.36  1.44  1.45  1.47   ... 5.65   \
# 0     NaN  Female   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4     NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ..    ...     ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 239   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 240   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 241   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 242   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 243   NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
# ...
