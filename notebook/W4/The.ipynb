# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a=[1,2,3,4,5,6,7,8,9]

# %%
# %timeit -n100 np.vectorize(lambda x: True if x % 2 == 0 else False)
# Out:
# The slowest run took 4.04 times longer than the fastest. This could mean that an intermediate result is being cached.
# 2.79 µs ± 1.42 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
df = pd.read_csv("../../../../../Downloads/archive/CAvideos.csv")

# %%
df['likes'].plot.box()
# Out:
# <Axes: >
