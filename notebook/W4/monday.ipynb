# %%
import pandas as pd

# %%
df = pd.read_csv("/home/rahmani/Downloads/archive/CAvideos.csv")

# %%
df.head(2)
# Out:
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1  0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1     iDubbbzTV           23  2017-11-13T17:00:00.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# 1  plush|"bad unboxing"|"unboxing"|"fan mail"|"id...   1014651  127794
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
# 1      1688          13030  https://i.ytimg.com/vi/0dBIkQ4Mz1M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   title                   40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   publish_time            40881 non-null  object
#  6   tags                    40881 non-null  object
#  7   views                   40881 non-null  int64
#  8   likes                   40881 non-null  int64
#  9   dislikes                40881 non-null  int64
#  10  comment_count           40881 non-null  int64
#  11  thumbnail_link          40881 non-null  object
#  12  comments_disabled       40881 non-null  bool
#  13  ratings_disabled        40881 non-null  bool
# ...

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40881.000000  4.088100e+04  4.088100e+04  4.088100e+04   4.088100e+04
# mean      20.795553  1.147036e+06  3.958269e+04  2.009195e+03   5.042975e+03
# std        6.775054  3.390913e+06  1.326895e+05  1.900837e+04   2.157902e+04
# min        1.000000  7.330000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       20.000000  1.439020e+05  2.191000e+03  9.900000e+01   4.170000e+02
# 50%       24.000000  3.712040e+05  8.780000e+03  3.030000e+02   1.301000e+03
# 75%       24.000000  9.633020e+05  2.871700e+04  9.500000e+02   3.713000e+03
# max       43.000000  1.378431e+08  5.053338e+06  1.602383e+06   1.114800e+06

# %%
df.sort_values('publish_time', ascending=False)
# Out:
#           video_id trending_date  \
# 40829  gFio_8aUS4I      18.14.06
# 40763  hyXwQBjreW0      18.14.06
# 40726  nBfJVvqNoJ0      18.14.06
# 40745  vUALE5SitT0      18.14.06
# 40875  7E1np354AEc      18.14.06
# ...            ...           ...
# 4014   rrkW65P-5sc      17.04.12
# 4230   rrkW65P-5sc      17.05.12
# 4585   rrkW65P-5sc      17.06.12
# 12443  hTSAyR3nOR0      18.17.01
# 12685  hTSAyR3nOR0      18.18.01
#
#                                                    title       channel_title  \
# 40829  Sam Harris LIVE: Trump, Consciousness, Jordan ...    The Rubin Report
# 40763  6ix9ine pulls up to O Block after arguing w/ F...        DJ Akademiks
# 40726  مسلسل أيوب بطولة مصطفى شعبان – الحلقة الثامنة ...  AlHayah TV Network
# 40745      BLACKPINK - ‘뚜두뚜두 (DDU-DU DDU-DU)’ M/V TEASER           BLACKPINK
# 40875        Вечер с Владимиром Соловьевым от 13.06.2018           Россия 24
# ...                                                  ...                 ...
# ...

# %%
df['channel_title'].value_counts()
# Out:
# channel_title
# SET India            192
# MSNBC                189
# FBE                  188
# The Young Turks      186
# REACT                183
#                     ...
# lovelyti2002           1
# It's Black Friday      1
# VTR Videos             1
# MyBigHairyArse         1
# Aja The Kween          1
# Name: count, Length: 5076, dtype: int64

# %%
# df.groupby('channel_title').aggregate('count').sort_values()
df.groupby('channel_title').size()
# Out:
# channel_title
# #AndresSTyle              3
# #Mind Warehouse          34
# #SeekingTheTruth          1
# * Martyna *               3
# - 欢迎订阅 -浙江卫视【奔跑吧】官方频道    36
#                          ..
# 창조영감클럽                    1
# 타우TV                      1
# 포스트쉐어                     1
# 포크포크                      1
# 활력소TV                     1
# Length: 5076, dtype: int64

# %%
for i,j in df.items():
    print(i,j)
    break
# Out:
# video_id 0        n1WpP7iowLc
# 1        0dBIkQ4Mz1M
# 2        5qpjK5DgCt4
# 3        d380meD0W0M
# 4        2Vv-BfVoq4g
#             ...
# 40876    sGolxsMSGfQ
# 40877    8HNuRNi8t70
# 40878    GWlKEM3m2EE
# 40879    lbMKLzQ4cNQ
# 40880    POTgw38-m58
# Name: video_id, Length: 40881, dtype: object
