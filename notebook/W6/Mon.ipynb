# %%
import pandas as pd 
import numpy as np

# %%
raw_df = pd.read_csv('../../datasets/AirQuality.csv',sep=';', na_values=-200)

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         7765 non-null   object
#  3   PT08.S1(CO)    8991 non-null   float64
#  4   NMHC(GT)       914 non-null    float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  8991 non-null   float64
#  7   NOx(GT)        7718 non-null   float64
#  8   PT08.S3(NOx)   8991 non-null   float64
#  9   NO2(GT)        7715 non-null   float64
#  10  PT08.S4(NO2)   8991 non-null   float64
#  11  PT08.S5(O3)    8991 non-null   float64
#  12  T              8991 non-null   object
#  13  RH             8991 non-null   object
#  14  AH             8991 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# ...

# %%
df = raw_df.drop(['Unnamed: 15','Unnamed: 16'],axis=1)
df = df.dropna(thresh=1,axis=0) 
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0       NaN     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0       NaN     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0       NaN     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0       NaN      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0       NaN     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
# df['CO(GT)']=df['CO(GT)'].map(lambda x: float(x.replace(',','.')))
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)            object
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                 object
# RH                object
# AH                object
# dtype: object

# %%
df['C6H6(GT)']=df['C6H6(GT)'].map(lambda x: float(x.replace(',','.')))

# %%
df['T']=df['T'].map(lambda x: float(x.replace(',','.')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[326], line 1
# ----> 1 df['T']=df['T'].map(lambda x: float(x.replace(',','.')))
#
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/series.py:4397, in Series.map(self, arg, na_action)
#    4318 def map(
#    4319     self,
#    4320     arg: Callable | Mapping | Series,
#    4321     na_action: Literal["ignore"] | None = None,
#    4322 ) -> Series:
#    4323     """
#    4324     Map values of Series according to an input mapping or function.
#    4325
#    (...)
#    4395     dtype: object
#    4396     """
# -> 4397     new_values = self._map_values(arg, na_action=na_action)
#    4398     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4399         self, method="map"
#    4400     )
#
# ...

# %%
df['RH']=df['RH'].map(lambda x: float(x.replace(',','.'))) 
df['AH']=df['AH'].map(lambda x: float(x.replace(',','.')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[327], line 1
# ----> 1 df['RH']=df['RH'].map(lambda x: float(x.replace(',','.')))
#       2 df['AH']=df['AH'].map(lambda x: float(x.replace(',','.')))
#
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/series.py:4397, in Series.map(self, arg, na_action)
#    4318 def map(
#    4319     self,
#    4320     arg: Callable | Mapping | Series,
#    4321     na_action: Literal["ignore"] | None = None,
#    4322 ) -> Series:
#    4323     """
#    4324     Map values of Series according to an input mapping or function.
#    4325
#    (...)
#    4395     dtype: object
#    4396     """
# -> 4397     new_values = self._map_values(arg, na_action=na_action)
#    4398     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4399         self, method="map"
#    4400     )
#
# ...

# %%
target_fields = df.keys()[2:]
x={}

for i in target_fields:
    # x[i]=df[i].gt(20.0).count()
    x[i]= df[i].loc[df[i].lt(0)].count()
x
(df.iloc[:,2:] < 0).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[328], line 6
#       2 x={}
#       4 for i in target_fields:
#       5     # x[i]=df[i].gt(20.0).count()
# ----> 6     x[i]= df[i].loc[df[i].lt(0)].count()
#       7 x
#       8 (df.iloc[:,2:] < 0).sum()
#
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/ops/__init__.py:201, in flex_method_SERIES.<locals>.flex_wrapper(self, other, level, fill_value, axis)
#     198 if fill_value is not None:
#     199     self = self.fillna(fill_value)
# --> 201 return op(self, other)
#
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# ...

# %%
df = df.replace(-200, np.nan)

# %%
# df["Date"]= pd.to_datetime(df["Date"],format='%d/%m/%Y')
# df["Date"]= 
df['date_time']=df['Date'] + ' ' + df['Time']
df['date_time'] = pd.to_datetime(df['date_time'] ,format='%d/%m/%Y %H.%M.%S')

# %%
df = df.set_index('date_time',drop=True)
df.sort_index()
# Out:
#                            Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# date_time
# 2004-03-10 18:00:00  10/03/2004  18.00.00    2,6       1360.0     150.0
# 2004-03-10 19:00:00  10/03/2004  19.00.00      2       1292.0     112.0
# 2004-03-10 20:00:00  10/03/2004  20.00.00    2,2       1402.0      88.0
# 2004-03-10 21:00:00  10/03/2004  21.00.00    2,2       1376.0      80.0
# 2004-03-10 22:00:00  10/03/2004  22.00.00    1,6       1272.0      51.0
# ...                         ...       ...    ...          ...       ...
# 2005-04-04 10:00:00  04/04/2005  10.00.00    3,1       1314.0       NaN
# 2005-04-04 11:00:00  04/04/2005  11.00.00    2,4       1163.0       NaN
# 2005-04-04 12:00:00  04/04/2005  12.00.00    2,4       1142.0       NaN
# 2005-04-04 13:00:00  04/04/2005  13.00.00    2,1       1003.0       NaN
# 2005-04-04 14:00:00  04/04/2005  14.00.00    2,2       1071.0       NaN
#
#                      C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# date_time
# ...

# %%
df = df.drop(['Date','Time'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[299], line 1
# ----> 1 df = df.drop(['Date','Time'],axis=1)
#
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
target = df['2004-02-05 00:00:00':'2004-04-15 00:00:00']

# %%
target=target.interpolate(method='time')

# %%
target - target.shift(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~/work/envs/ML/lib/python3.11/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'NoneType'
#
# ...

# %%
target.resample('m')

# %%
df[['NMHC(GT)']].rolling(window=1).mean()
# Out:
#                      NMHC(GT)
# date_time
# 2004-03-10 18:00:00     150.0
# 2004-03-10 19:00:00     112.0
# 2004-03-10 20:00:00      88.0
# 2004-03-10 21:00:00      80.0
# 2004-03-10 22:00:00      51.0
# ...                       ...
# 2005-04-04 10:00:00       NaN
# 2005-04-04 11:00:00       NaN
# 2005-04-04 12:00:00       NaN
# 2005-04-04 13:00:00       NaN
# 2005-04-04 14:00:00       NaN
#
# [9357 rows x 1 columns]

# %%
df
# Out:
#                            Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# date_time
# 2004-03-10 18:00:00  10/03/2004  18.00.00    2,6       1360.0     150.0
# 2004-03-10 19:00:00  10/03/2004  19.00.00      2       1292.0     112.0
# 2004-03-10 20:00:00  10/03/2004  20.00.00    2,2       1402.0      88.0
# 2004-03-10 21:00:00  10/03/2004  21.00.00    2,2       1376.0      80.0
# 2004-03-10 22:00:00  10/03/2004  22.00.00    1,6       1272.0      51.0
# ...                         ...       ...    ...          ...       ...
# 2005-04-04 10:00:00  04/04/2005  10.00.00    3,1       1314.0       NaN
# 2005-04-04 11:00:00  04/04/2005  11.00.00    2,4       1163.0       NaN
# 2005-04-04 12:00:00  04/04/2005  12.00.00    2,4       1142.0       NaN
# 2005-04-04 13:00:00  04/04/2005  13.00.00    2,1       1003.0       NaN
# 2005-04-04 14:00:00  04/04/2005  14.00.00    2,2       1071.0       NaN
#
#                      C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# date_time
# ...
