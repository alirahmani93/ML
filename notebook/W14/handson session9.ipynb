# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
# extra code – the exact arguments of make_blobs() are not important
blob_centers = np.array([[ 0.2,  2.3], [-1.5 ,  2.3], [-2.8,  1.8],
                         [-2.8,  2.8], [-2.8,  1.3]])
blob_std = np.array([0.4, 0.3, 0.1, 0.1, 0.1])
X, y = make_blobs(n_samples=2000, centers=blob_centers, cluster_std=blob_std,
                  random_state=7)

k = 5
kmeans = KMeans(n_clusters=k, n_init=10,init='random', random_state=42)
y_pred = kmeans.fit_predict(X)

# %%
def plot_clusters(X, y=None):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=1)
    plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=12)
    plt.xlabel("$x_1$")
    plt.ylabel("$x_2$", rotation=0)

# %%
plt.figure(figsize=(8, 4))
plot_clusters(X)
plt.gca().set_axisbelow(True)
plt.grid()
plt.show()

# %%
kmeans.labels_ , kmeans.labels_.shape, kmeans.cluster_centers_
# Out:
# (array([2, 1, 0, ..., 4, 0, 1], dtype=int32),
#  (2000,),
#  array([[ 0.20876306,  2.25551336],
#         [-2.80389616,  1.80117999],
#         [-2.80037642,  1.30082566],
#         [-1.46679593,  2.28585348],
#         [-2.79290307,  2.79641063]]))

# %%
kmeans.inertia_,kmeans.n_iter_
# Out:
# (211.5985372581684, 3)

# %%
sklearn.metrics.silhouette_score(X, kmeans.labels_), sklearn.metrics.silhouette_samples(X, kmeans.labels_)
# Out:
# (0.655517642572828,
#  array([0.66694071, 0.73103018, 0.48656361, ..., 0.846275  , 0.70971862,
#         0.62920907]))
